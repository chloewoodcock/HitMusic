# %% [markdown]
# # Importing Original Dataset

# %%
import pandas as pd
from matplotlib.pyplot

# %%
#This is the dataset created by Dhruvil Dave form Kaggle.com
df = pd.read_csv("charts.csv", error_bad_lines=False)

# %%
df
# Out:
#               date  rank                                 song  \
# 0       2021-11-06     1                           Easy On Me
# 1       2021-11-06     2                                 Stay
# 2       2021-11-06     3                        Industry Baby
# 3       2021-11-06     4                           Fancy Like
# 4       2021-11-06     5                           Bad Habits
# ...            ...   ...                                  ...
# 330082  1958-08-04    96                        Over And Over
# 330083  1958-08-04    97                     I Believe In You
# 330084  1958-08-04    98                      Little Serenade
# 330085  1958-08-04    99  I'll Get By (As Long As I Have You)
# 330086  1958-08-04   100                                 Judy
#
#                                artist  last-week  peak-rank  weeks-on-board
# 0                               Adele        1.0          1               3
# ...

# %%
#Adele = df[df.artist == 'Adele']

# %%
#Adele['song'].nunique()
# Out:
# 14

# %%
#filter out each year
import datetime as dt
df['date'] = pd.to_datetime(df['date'])

data_2015 = df[df['date'].dt.year == 2015]
data_2016 = df[df['date'].dt.year == 2016]
data_2017 = df[df['date'].dt.year == 2017]
data_2018 = df[df['date'].dt.year == 2018]
data_2019 = df[df['date'].dt.year == 2019]
data_2020 = df[df['date'].dt.year == 2020]

# %%
#concatenate together
data_2015_2020 = pd.concat([data_2020, data_2019, data_2018, data_2017, data_2016, data_2015])

# %%
data_2015_2020 = data_2015_2020.reset_index()

# %%
data_2015_2020
# Out:
#        index       date  rank                               song  \
# 0       4500 2020-12-26     1                             Willow
# 1       4501 2020-12-26     2    All I Want For Christmas Is You
# 2       4502 2020-12-26     3  Rockin' Around The Christmas Tree
# 3       4503 2020-12-26     4                   Jingle Bell Rock
# 4       4504 2020-12-26     5                               Mood
# ...      ...        ...   ...                                ...
# 31295  35795 2015-01-03    96                           Fireball
# 31296  35796 2015-01-03    97                    Homegrown Honey
# 31297  35797 2015-01-03    98                         Wet Dreamz
# 31298  35798 2015-01-03    99                Yellow Flicker Beat
# 31299  35799 2015-01-03   100                       In Your Arms
#
#                              artist  last-week  peak-rank  weeks-on-board
# 0                      Taylor Swift        NaN          1               1
# ...

# %%
#drop duplicates
data_duplicates = data_2015_2020.drop_duplicates(subset=['song', 'artist'])

# %%
data_duplicates
# Out:
#        index       date  rank                               song  \
# 0       4500 2020-12-26     1                             Willow
# 1       4501 2020-12-26     2    All I Want For Christmas Is You
# 2       4502 2020-12-26     3  Rockin' Around The Christmas Tree
# 3       4503 2020-12-26     4                   Jingle Bell Rock
# 4       4504 2020-12-26     5                               Mood
# ...      ...        ...   ...                                ...
# 31273  35773 2015-01-03    74                            Soldier
# 31282  35782 2015-01-03    83                         Lost Stars
# 31283  35783 2015-01-03    84             Girl In A Country Song
# 31287  35787 2015-01-03    88                  Get On Your Knees
# 31295  35795 2015-01-03    96                           Fireball
#
#                                     artist  last-week  peak-rank  \
# 0                             Taylor Swift        NaN          1
# ...

# %%
#filter years
data_2010 = df[df['date'].dt.year == 2010]
data_2011 = df[df['date'].dt.year == 2011]
data_2012 = df[df['date'].dt.year == 2012]
data_2013 = df[df['date'].dt.year == 2013]
data_2014 = df[df['date'].dt.year == 2014]

# %%
#concatenate together
data_2010_2020 = pd.concat([data_2020, data_2019, data_2018, data_2017, data_2016, data_2015, 
                           data_2014, data_2013, data_2012, data_2011, data_2010])

# %%
data_2010_2020 = data_2010_2020.reset_index()

# %%
data_2010_2020
# Out:
#        index       date  rank                               song  \
# 0       4500 2020-12-26     1                             Willow
# 1       4501 2020-12-26     2    All I Want For Christmas Is You
# 2       4502 2020-12-26     3  Rockin' Around The Christmas Tree
# 3       4503 2020-12-26     4                   Jingle Bell Rock
# 4       4504 2020-12-26     5                               Mood
# ...      ...        ...   ...                                ...
# 57395  61895 2010-01-02    96                   Kings And Queens
# 57396  61896 2010-01-02    97                       I'm Going In
# 57397  61897 2010-01-02    98                        I Get It In
# 57398  61898 2010-01-02    99                        Drop It Low
# 57399  61899 2010-01-02   100                        Video Phone
#
#                                         artist  last-week  peak-rank  \
# 0                                 Taylor Swift        NaN          1
# ...

# %%
#remove duplicates
data_duplicates2 = data_2010_2020.drop_duplicates(subset=['song', 'artist'])

# %%
data_duplicates2
# Out:
#        index       date  rank                                        song  \
# 0       4500 2020-12-26     1                                      Willow
# 1       4501 2020-12-26     2             All I Want For Christmas Is You
# 2       4502 2020-12-26     3           Rockin' Around The Christmas Tree
# 3       4503 2020-12-26     4                            Jingle Bell Rock
# 4       4504 2020-12-26     5                                        Mood
# ...      ...        ...   ...                                         ...
# 57328  61828 2010-01-02    29                           Hell Breaks Loose
# 57354  61854 2010-01-02    55  Empire State Of Mind (Part II) Broken Down
# 57366  61866 2010-01-02    67                                    Elevator
# 57383  61883 2010-01-02    84                                     On Fire
# 57397  61897 2010-01-02    98                                 I Get It In
#
#                              artist  last-week  peak-rank  weeks-on-board
# ...

# %%
#save new datasets
data_duplicates.to_csv (r'2015_2020_noDuplicates.csv', header=True)
data_duplicates2.to_csv (r'2010_2020_noDuplicates.csv', header=True)
